# %%
import os
import pandas as pd
import numpy as np
from pydataset import data
from env import get_connection

pd.options.display.max_columns = None

# %% [markdown]
# # Acquisition Exercises

# %% [markdown]
# ## Part 1:

# %% [markdown]
# 1. Make a new repo called classification-exercises on both GitHub and within your codeup-data-science directory. This will be where you do your work for this module.

# %%
#Done

# %% [markdown]
# 2. Inside of your local classification-exercises repo, create a file named .gitignore with the following contents:
#
# - env.py
# - .DS_Store
# - .ipynb_checkpoints/
# - __pycache__
# - *.csv
#
# Add and commit your .gitignore file before moving forward.

# %%
#Done

# %% [markdown]
# 3. Now that you are 100% sure that your .gitignore file lists env.py, create or copy your env.py file inside of classification-exercises. Running git status should show that git is ignoring this file.

# %%
#Done

# %% [markdown]
# 4. In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
df_iris = data('iris')
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# - print the first 3 rows

# %%
#Seaborn has a slightly different structure:
print(df_iris[0:3])
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# - print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# - print the column names

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# - print the data type of each column

# %%
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %% [markdown]
# - print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_iris.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# Sepal.Length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal.Width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# Petal.Length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# Petal.Width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# 5. Read the data from this google sheet into a dataframe, df_google.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
df_google = pd.read_csv(csv_export_url)
#df_google.head()
# Throwing an error "RemoteDisconnected: Remote end closed connection without response"
# For some reason its working now on my home network. That is the only thing that changed.

# %% [markdown]
# - print the first 3 rows

# %%
print(df_google[0:3])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# - print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# - print the column names

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - print the data type of each column

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# - print the summary statistics for each of the numeric variables

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - print the unique values for each of your categorical variables

# %%
print("---------------------------------------------------------------")
print(df_google.Name.unique())
print("---------------------------------------------------------------")
print(df_google.Sex.unique())
print("---------------------------------------------------------------")
print(df_google.Ticket.unique())
print("---------------------------------------------------------------")
print(df_google.Cabin.unique())
print("---------------------------------------------------------------")
print(df_google.Embarked.unique())
print("---------------------------------------------------------------")
# Out:
# ---------------------------------------------------------------
# ['Braund, Mr. Owen Harris'
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
#  'Heikkinen, Miss. Laina' 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'
#  'Allen, Mr. William Henry' 'Moran, Mr. James' 'McCarthy, Mr. Timothy J'
#  'Palsson, Master. Gosta Leonard'
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'
#  'Nasser, Mrs. Nicholas (Adele Achem)' 'Sandstrom, Miss. Marguerite Rut'
#  'Bonnell, Miss. Elizabeth' 'Saundercock, Mr. William Henry'
#  'Andersson, Mr. Anders Johan' 'Vestrom, Miss. Hulda Amanda Adolfina'
#  'Hewlett, Mrs. (Mary D Kingcome) ' 'Rice, Master. Eugene'
#  'Williams, Mr. Charles Eugene'
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)'
#  'Masselmani, Mrs. Fatima' 'Fynney, Mr. Joseph J' 'Beesley, Mr. Lawrence'
#  'McGowan, Miss. Anna "Annie"' 'Sloper, Mr. William Thompson'
#  'Palsson, Miss. Torborg Danira'
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)'
# ...

# %%
df_google.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# You would have to do this for each column:
df_google.Pclass.value_counts(dropna=False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# 6. Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
df_excel = pd.read_excel('train.xlsx', sheet_name='train')
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# - assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel[0:100]
df_excel_sample.tail()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 95           96         0       3           Shorney, Mr. Charles Joseph
# 96           97         0       1             Goldschmidt, Mr. George B
# 97           98         1       1       Greenfield, Mr. William Bertram
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99          100         0       2                     Kantor, Mr. Sinai
#
#        Sex   Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 95    male   NaN      0      0    374910   8.0500      NaN        S
# 96    male  71.0      0      0  PC 17754  34.6542       A5        C
# 97    male  23.0      0      1  PC 17759  63.3583  D10 D12        C
# 98  female  34.0      0      1    231919  23.0000      NaN        S
# 99    male  34.0      1      0    244367  26.0000      NaN        S

# %% [markdown]
# - print the number of rows of your original dataframe

# %%
df_excel.shape[0]
# Out:
# 891

# %% [markdown]
# - print the first 5 column names

# %%
df_excel.columns[0:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# - print the column names that have a data type of object

# %%
df_object = df_excel.dtypes == 'object'
df_object[df_object == True]
# Out:
# Name        True
# Sex         True
# Ticket      True
# Cabin       True
# Embarked    True
# dtype: bool

# %% [markdown]
# - compute the range for each of the numeric variables.

# %%
# You could use the df_excel.describe().T to flip the rows/columns.

# %%
df_range = df_excel.describe().loc['max'] - df_excel.describe().loc['min']
df_range
# Out:
# PassengerId    890.0000
# Survived         1.0000
# Pclass           2.0000
# Age             79.5800
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %% [markdown]
# ## Part 2:

# %% [markdown]
# Make a new python module, acquire.py to hold the following data aquisition functions:

# %% [markdown]
# 1. Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
def get_titanic_data():
    
    """
    This function reads the titanic data from Codeup db into a df.
    """
    filename = "titanic.csv"
    
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        # read the SQL query into a dataframe
        df = pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))
        
        # Write that dataframe to disk for later. Called "caching" the data for later.
        df.to_csv(filename)
        
        # Return the dataframe to the calling code
        return df

# %%
titanic_df = get_titanic_data()

# %%
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %% [markdown]
# 2. Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.

# %%
def get_iris_data():
    """
    This function reads the iris data from Codeup db into a df.
    """
    filename = "iris.csv"
    
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        query = """
        SELECT sepal_length, sepal_width, petal_length, petal_width, species_name, species_id FROM measurements
        LEFT JOIN species USING (species_id);
        """
        # read the SQL query into a dataframe
        df = pd.read_sql(query, get_connection('iris_db'))
        
        # Write that dataframe to disk for later. Called "caching" the data for later.
        df.to_csv(filename)
        
        # Return the dataframe to the calling code
        return df

# %%
iris_df = get_iris_data()
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species_name  \
# 0           5.1          3.5           1.4          0.2       setosa
# 1           4.9          3.0           1.4          0.2       setosa
# 2           4.7          3.2           1.3          0.2       setosa
# 3           4.6          3.1           1.5          0.2       setosa
# 4           5.0          3.6           1.4          0.2       setosa
#
#    species_id
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# 3. Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join contract_types, internet_service_types, payment_types tables with the customers table, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.

# %%
def get_telco_data():
    """
    This function reads the telco_churn data from Codeup db into a df.
    """
    filename = "telco_churn.csv"
    
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        # read the SQL query into a dataframe
        query = """
        SELECT * FROM customers 
        LEFT JOIN contract_types USING (contract_type_id)
        LEFT JOIN internet_service_types USING (internet_service_type_id)
        LEFT JOIN payment_types USING (payment_type_id);
        """
        df = pd.read_sql(query, get_connection('telco_churn'))
        
        # Write that dataframe to disk for later. Called "caching" the data for later.
        df.to_csv(filename)
        
        # Return the dataframe to the calling code
        return df

# %%
telco_df = get_telco_data()

# %%
telco_df.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection tech_support  \
# ...

# %% [markdown]
# 4. Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
# Done

# %% [markdown]
# # Preparation Exercises

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# import splitting and imputing functions
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# turn off pink boxes for demo
import warnings
warnings.filterwarnings("ignore")

# import our own acquire module
import acquire
import prepare

pd.options.display.max_columns = None

# %% [markdown]
# Using the Iris Data:

# %% [markdown]
# 1. Use the function defined in acquire.py to load the iris data.

# %%
iris = acquire.get_iris_data()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species_name  \
# 0           5.1          3.5           1.4          0.2       setosa
# 1           4.9          3.0           1.4          0.2       setosa
# 2           4.7          3.2           1.3          0.2       setosa
# 3           4.6          3.1           1.5          0.2       setosa
# 4           5.0          3.6           1.4          0.2       setosa
#
#    species_id
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# 2. Drop the species_id and measurement_id columns.

# %%
cols_to_drop = ['species_id'] #Never imported the measurements_id column

# %%
iris = iris.drop(columns=cols_to_drop)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species_name'],
#       dtype='object')

# %% [markdown]
# 3. Rename the species_name column to just species.

# %%
iris.rename(columns={'species_name':'species'}, inplace=True)

# %% [markdown]
# 4. Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %%
dummy_df = pd.get_dummies(iris[['species']], drop_first=True)

# %%
dummy_df.sample(5)
# Out:
#      species_versicolor  species_virginica
# 118                   0                  1
# 38                    0                  0
# 30                    0                  0
# 95                    1                  0
# 102                   0                  1

# %%
iris = pd.concat([iris, dummy_df], axis=1)

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 34            4.9          3.1           1.5          0.2      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 120           6.9          3.2           5.7          2.3   virginica
# 79            5.7          2.6           3.5          1.0  versicolor
# 40            5.0          3.5           1.3          0.3      setosa
#
#      species_versicolor  species_virginica
# 34                    0                  0
# 33                    0                  0
# 120                   0                  1
# 79                    1                  0
# 40                    0                  0

# %% [markdown]
# 5. Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris(df):
    """ 
    This function takes a dataframe from the iris dataset 
    containing the sepal_length, sepal_width, petal_length, 
    petal_width, species_name, species_id columns and returns 
    a cleaner dataset.
    """
    #Assigns column to a list and drops species_id:
    cols_to_drop = ['species_id'] #Never imported the measurements_id column
    df = df.drop(columns=cols_to_drop)
    
    #Shortens the species column name:
    df.rename(columns={'species_name':'species'}, inplace=True)
    
    #Assigns two dummy columns and attach them to the dataframe.
    dummy_df = pd.get_dummies(df[['species']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
iris_test = acquire.get_iris_data()
iris_test = prep_iris(iris_test)

# %%
iris_test.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 109           7.2          3.6           6.1          2.5   virginica
# 85            6.0          3.4           4.5          1.6  versicolor
# 20            5.4          3.4           1.7          0.2      setosa
# 141           6.9          3.1           5.1          2.3   virginica
# 143           6.8          3.2           5.9          2.3   virginica
#
#      species_versicolor  species_virginica
# 109                   0                  1
# 85                    1                  0
# 20                    0                  0
# 141                   0                  1
# 143                   0                  1

# %% [markdown]
# Using the Titanic dataset
#
# 1. Use the function defined in acquire.py to load the Titanic data.

# %%
titanic_df = get_titanic_data()
titanic_df.sample(5)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch    fare  \
# 813           813         0       3  female   6.0      4      2  31.275
# 724           724         1       1    male  27.0      1      0  53.100
# 654           654         0       3  female  18.0      0      0   6.750
# 23             23         1       1    male  28.0      0      0  35.500
# 123           123         1       2  female  32.5      0      0  13.000
#
#     embarked   class deck  embark_town  alone
# 813        S   Third  NaN  Southampton      0
# 724        S   First    E  Southampton      0
# 654        Q   Third  NaN   Queenstown      1
# 23         S   First    A  Southampton      1
# 123        S  Second    E  Southampton      1

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns.

# %%
cols_to_drop = ['passenger_id', 'age', 'embarked', 'class', 'deck']

# %%
titanic_df.drop(columns=cols_to_drop, inplace = True)

# %%
titanic_df.sample(5)
# Out:
#      survived  pclass     sex  sibsp  parch    fare  embark_town  alone
# 649         1       3  female      0      0   7.550  Southampton      1
# 304         0       3    male      0      0   8.050  Southampton      1
# 129         0       3    male      0      0   6.975  Southampton      1
# 818         0       3    male      0      0   6.450  Southampton      1
# 312         0       2  female      1      1  26.000  Southampton      0

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummy_df = pd.get_dummies(titanic_df[['sex', 'embark_town']], drop_first=True)

# %%
titanic_df = pd.concat([titanic_df, dummy_df], axis=1)

# %%
titanic_df.sample(5)
# Out:
#      survived  pclass     sex  sibsp  parch      fare  embark_town  alone  \
# 353         0       3    male      1      0   17.8000  Southampton      0
# 659         0       1    male      0      2  113.2750    Cherbourg      0
# 813         0       3  female      4      2   31.2750  Southampton      0
# 103         0       3    male      0      0    8.6542  Southampton      1
# 455         1       3    male      0      0    7.8958    Cherbourg      1
#
#      sex_male  embark_town_Queenstown  embark_town_Southampton
# 353         1                       0                        1
# 659         1                       0                        0
# 813         0                       0                        1
# 103         1                       0                        1
# 455         1                       0                        0

# %% [markdown]
# 4. Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def prep_titanic(df):
    """
    This function takes a dataframe with the titantic data set
    and areturns a cleaner version.
    """
    
    cols_to_drop = ['passenger_id', 'age', 'embarked', 'class', 'deck']
    df.drop(columns=cols_to_drop, inplace = True)
    dummy_df = pd.get_dummies(df[['sex', 'embark_town']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %%
test_df = get_titanic_data()
prep_titanic(test_df)
# Out:
#      survived  pclass     sex  sibsp  parch     fare  embark_town  alone  \
# 0           0       3    male      1      0   7.2500  Southampton      0
# 1           1       1  female      1      0  71.2833    Cherbourg      0
# 2           1       3  female      0      0   7.9250  Southampton      1
# 3           1       1  female      1      0  53.1000  Southampton      0
# 4           0       3    male      0      0   8.0500  Southampton      1
# ..        ...     ...     ...    ...    ...      ...          ...    ...
# 886         0       2    male      0      0  13.0000  Southampton      1
# 887         1       1  female      0      0  30.0000  Southampton      1
# 888         0       3  female      1      2  23.4500  Southampton      0
# 889         1       1    male      0      0  30.0000    Cherbourg      1
# 890         0       3    male      0      0   7.7500   Queenstown      1
#
#      sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# Using the Telco dataset
#
# 1. Use the function defined in acquire.py to load the Telco data.

# %%
telco_df = get_telco_data()

# %%
telco_df.columns
# Out:
# Index(['payment_type_id', 'internet_service_type_id', 'contract_type_id',
#        'customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'online_security',
#        'online_backup', 'device_protection', 'tech_support', 'streaming_tv',
#        'streaming_movies', 'paperless_billing', 'monthly_charges',
#        'total_charges', 'churn', 'contract_type', 'internet_service_type',
#        'payment_type'],
#       dtype='object')

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
cols_to_drop = ['customer_id', 'payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id']

# %%
telco_df.drop(columns=cols_to_drop, inplace = True)

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
encode_list = ['churn', 'paperless_billing', 'partner' , 'dependents']

# %%
for col in telco_df.columns:
    if col in encode_list:
        telco_df[col] = telco_df[col].replace({'Yes':True,'No':False}).astype('int')

# %%
dummy_df = (pd.get_dummies(telco_df[['gender', 'partner', 'streaming_movies', 
                                     'streaming_tv' , 'tech_support', 'dependents', 'multiple_lines', 
                                     'online_backup', 'online_security', 'device_protection', 
                                     'payment_type', 'internet_service_type', 'contract_type']], drop_first=True))
telco_df = pd.concat([telco_df, dummy_df], axis=1)

# %%
telco_df.sample(5)
# Out:
#       gender  senior_citizen  partner  dependents  tenure phone_service  \
# 6258    Male               0        1           0      63           Yes
# 1690    Male               0        0           0       1           Yes
# 794   Female               0        1           1      16           Yes
# 4314    Male               0        1           1      23           Yes
# 5105  Female               0        0           0      25           Yes
#
#      multiple_lines      online_security        online_backup  \
# 6258             No  No internet service  No internet service
# 1690             No  No internet service  No internet service
# 794              No  No internet service  No internet service
# 4314             No  No internet service  No internet service
# 5105             No                  Yes                   No
#
#         device_protection         tech_support         streaming_tv  \
# 6258  No internet service  No internet service  No internet service
# ...

# %% [markdown]
# 4. Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def prep_telco(working_df):
    
    
    cols_to_drop = ['customer_id', 'payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id']
    
    working_df.drop(columns=cols_to_drop, inplace = True)
    
    encode_list = ['churn', 'paperless_billing', 'partner' , 'dependents']
    
    for col in working_df.columns:
        if col in encode_list:
            working_df[col] = working_df[col].replace({'Yes':True,'No':False}).astype('int')
            
    dummy_df = (pd.get_dummies(working_df[['gender', 'partner', 'streaming_movies', 'streaming_tv' , 'tech_support','dependents', 'multiple_lines', 'online_backup', 'online_security', 'device_protection', 'payment_type', 'internet_service_type', 'contract_type']], drop_first=True))
    
    working_df = pd.concat([working_df, dummy_df], axis=1)
    
    return working_df

# %% [markdown]
# Split your data
#
# 1. Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
# 20% test, 80% train_validate
# then of the 80% train_validate: 30% validate, 70% train. 
def train_validate(df, stratify_col = None):
    """
    This function takes in a DataFrame and column name for the stratify argument (defualt is None).
    It will split the data into three parts for training, testing and validating.
    """
    #This is logic to set the stratify argument:
    stratify_arg = ''
    if stratify_col != None:
        stratify_arg = df[stratify_col]
    else:
        stratify_arg = None
    
    #This splits the DataFrame into 'train' and 'test':
    train, test = train_test_split(df, test_size=.2, random_state=123, stratify=stratify_arg)
    
    #The length of the stratify column changed and needs to be adjusted:
    if stratify_col != None:
        stratify_arg = train[stratify_col]
        
    #This splits the larger 'train' DataFrame into a smaller 'train' and 'validate' DataFrames:
    train, validate = train_test_split(train, test_size=.3, random_state=123, stratify=stratify_arg)
    return train, validate, test

# %% [markdown]
# 2. Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %%
df = acquire.get_iris_data()

# %%
df = prepare.prep_iris(df)

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 118           7.7          2.6           6.9          2.3   virginica
# 28            5.2          3.4           1.4          0.2      setosa
# 115           6.4          3.2           5.3          2.3   virginica
# 61            5.9          3.0           4.2          1.5  versicolor
# 73            6.1          2.8           4.7          1.2  versicolor
#
#      species_versicolor  species_virginica
# 118                   0                  1
# 28                    0                  0
# 115                   0                  1
# 61                    1                  0
# 73                    1                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal_length        150 non-null    float64
#  1   sepal_width         150 non-null    float64
#  2   petal_length        150 non-null    float64
#  3   petal_width         150 non-null    float64
#  4   species             150 non-null    object
#  5   species_versicolor  150 non-null    uint8
#  6   species_virginica   150 non-null    uint8
# dtypes: float64(4), object(1), uint8(2)
# memory usage: 6.3+ KB

# %%
train_iris, validate_iris, test_iris = train_validate(df, stratify_col = 'species')

# %%
train_iris.info(), validate_iris.info(), test_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 79 to 73
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal_length        84 non-null     float64
#  1   sepal_width         84 non-null     float64
#  2   petal_length        84 non-null     float64
#  3   petal_width         84 non-null     float64
#  4   species             84 non-null     object
#  5   species_versicolor  84 non-null     uint8
#  6   species_virginica   84 non-null     uint8
# dtypes: float64(4), object(1), uint8(2)
# memory usage: 4.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 134 to 124
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal_length        36 non-null     float64
#  1   sepal_width         36 non-null     float64
#  2   petal_length        36 non-null     float64
# ...

# %% [markdown]
# 3. Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %%
df = acquire.get_titanic_data()
df = prepare.prep_titanic(df)

# %%
train_titanic, validate_titanic, test_titanic = train_validate(df, 'survived')

# %%
train_titanic.info(), validate_titanic.info(), test_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 583 to 744
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   survived                 498 non-null    int64
#  1   pclass                   498 non-null    int64
#  2   sex                      498 non-null    object
#  3   sibsp                    498 non-null    int64
#  4   parch                    498 non-null    int64
#  5   fare                     498 non-null    float64
#  6   embark_town              497 non-null    object
#  7   alone                    498 non-null    int64
#  8   sex_male                 498 non-null    uint8
#  9   embark_town_Queenstown   498 non-null    uint8
#  10  embark_town_Southampton  498 non-null    uint8
# dtypes: float64(1), int64(5), object(2), uint8(3)
# memory usage: 36.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 610 to 26
# ...

# %% [markdown]
# 4. Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
df = acquire.get_telco_data()
df = prepare.prep_telco(df)

# %%
train_telco, validate_telco, test_telco = train_validate(df, 'churn')

# %%
train_telco.info(), validate_telco.info(), test_telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3943 entries, 5310 to 6817
# Data columns (total 44 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 3943 non-null   object
#  1   senior_citizen                         3943 non-null   int64
#  2   partner                                3943 non-null   int64
#  3   dependents                             3943 non-null   int64
#  4   tenure                                 3943 non-null   int64
#  5   phone_service                          3943 non-null   object
#  6   multiple_lines                         3943 non-null   object
#  7   online_security                        3943 non-null   object
#  8   online_backup                          3943 non-null   object
#  9   device_protection                      3943 non-null   object
# ...

# %% [markdown]
# # Exploratory Analysis Exercises

# %%
# 20% test, 80% train_validate
# then of the 80% train_validate: 30% validate, 70% train. 
def train_validate(df, stratify_col = None):
    """
    This function takes in a DataFrame and column name for the stratify argument (defualt is None).
    It will split the data into three parts for training, testing and validating.
    """
    #This is logic to set the stratify argument:
    stratify_arg = ''
    if stratify_col != None:
        stratify_arg = df[stratify_col]
    else:
        stratify_arg = None
    
    #This splits the DataFrame into 'train' and 'test':
    train, test = train_test_split(df, test_size=.2, stratify=stratify_arg, random_state = 321)
    
    #The length of the stratify column changed and needs to be adjusted:
    if stratify_col != None:
        stratify_arg = train[stratify_col]
        
    #This splits the larger 'train' DataFrame into a smaller 'train' and 'validate' DataFrames:
    train, validate = train_test_split(train, test_size=.3, stratify=stratify_arg, random_state = 321)
    return train, validate, test

# %% [markdown]
# ![image.png](attachment:4bbceb4d-26f3-42d0-a066-8551abe1378c.png)

# %% [markdown]
# ### 1. Acquire, prepare & split your data.

# %%
iris = prepare.prep_iris(acquire.get_iris_data())

# %%
train_iris, validate_iris, test_iris = train_validate(iris, stratify_col = 'species')

# %%
train_iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 144           6.7          3.3           5.7          2.5   virginica
# 123           6.3          2.7           4.9          1.8   virginica
# 54            6.5          2.8           4.6          1.5  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 136           6.3          3.4           5.6          2.4   virginica
#
#      species_versicolor  species_virginica
# 144                   0                  1
# 123                   0                  1
# 54                    1                  0
# 90                    1                  0
# 136                   0                  1

# %% [markdown]
# ### 2. Univariate Stats

# %% [markdown]
# - For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).
#
# - For each species (categorical variable): create a frequency table and a bar plot of those frequencies.
#
# - Document takeaways & any actions.

# %%
# identify the columns that are numeric
# then filter the df by those column names

# %%
train_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 2 to 142
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal_length        84 non-null     float64
#  1   sepal_width         84 non-null     float64
#  2   petal_length        84 non-null     float64
#  3   petal_width         84 non-null     float64
#  4   species             84 non-null     object
#  5   species_versicolor  84 non-null     uint8
#  6   species_virginica   84 non-null     uint8
# dtypes: float64(4), object(1), uint8(2)
# memory usage: 4.1+ KB

# %%
train_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  \
# count     84.000000    84.000000     84.000000    84.000000
# mean       5.863095     3.051190      3.775000     1.183333
# std        0.829106     0.444916      1.762588     0.762658
# min        4.300000     2.200000      1.100000     0.100000
# 25%        5.200000     2.775000      1.575000     0.200000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.425000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.700000     2.500000
#
#        species_versicolor  species_virginica
# count           84.000000          84.000000
# mean             0.333333           0.333333
# std              0.474236           0.474236
# min              0.000000           0.000000
# 25%              0.000000           0.000000
# 50%              0.000000           0.000000
# 75%              1.000000           1.000000
# max              1.000000           1.000000

# %%
# Check out distributions of numeric columns.

num_cols = train_iris.columns[[train_iris[col].dtype != 'object' for col in train_iris.columns]]
for col in num_cols:
    plt.hist(train_iris[col])
    plt.title(col)
    plt.ylabel("frequency")
    plt.show()
    #boxplot
    plt.boxplot(train_iris[col])
    plt.ylabel(col)
    plt.show()
    #descriptive statistics
    print(train_iris[col].describe())
# Out:
# count    84.000000
# mean      5.863095
# std       0.829106
# min       4.300000
# 25%       5.200000
# 50%       5.800000
# 75%       6.425000
# max       7.900000
# Name: sepal_length, dtype: float64
# count    84.000000
# mean      3.051190
# std       0.444916
# min       2.200000
# 25%       2.775000
# 50%       3.000000
# 75%       3.300000
# max       4.400000
# Name: sepal_width, dtype: float64
# count    84.000000
# mean      3.775000
# std       1.762588
# min       1.100000
# 25%       1.575000
# 50%       4.400000
# 75%       5.100000
# max       6.700000
# Name: petal_length, dtype: float64
# count    84.000000
# mean      1.183333
# std       0.762658
# min       0.100000
# 25%       0.200000
# 50%       1.300000
# 75%       1.800000
# max       2.500000
# Name: petal_width, dtype: float64
# count    84.000000
# mean      0.333333
# std       0.474236
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# ...

# %% [markdown]
# <span style="color:green">Takeaways:</span>
# - Sepal Length and Width are normally distributed
#
# - Petal Length and Width are bimodal with wide inner quartile range.

# %% [markdown]
# ### 3. Bivariate Stats

# %% [markdown]
# - Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).
#
# - For each measurement type, compute the descriptive statistics for each species.
#
# - For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.
#
# - Document takeaways & any actions.

# %%
for col in num_cols:
    sns.barplot(x='species', y=col, data=train_iris)
    plt.title(f'Average {col} for each species')
    overall_mean = train_iris[col].mean()
    plt.axhline(overall_mean, label=f'Mean {col}',
                color='rebeccapurple', linestyle='dotted')
    plt.legend()
    plt.show()

train_iris.groupby('species').describe().T
# Out:
# species                      setosa  versicolor  virginica
# sepal_length       count  28.000000   28.000000  28.000000
#                    mean    5.000000    6.003571   6.585714
#                    std     0.391578    0.412295   0.674792
#                    min     4.300000    5.500000   4.900000
#                    25%     4.775000    5.675000   6.300000
#                    50%     5.000000    5.950000   6.500000
#                    75%     5.200000    6.300000   6.875000
#                    max     5.800000    6.800000   7.900000
# sepal_width        count  28.000000   28.000000  28.000000
#                    mean    3.417857    2.757143   2.978571
#                    std     0.389733    0.334917   0.331503
#                    min     3.000000    2.200000   2.500000
#                    25%     3.100000    2.500000   2.775000
#                    50%     3.400000    2.750000   3.000000
#                    75%     3.725000    3.000000   3.050000
# ...

# %% [markdown]
# H0: There is no significant difference in the mean petal width for Virginica vs Versicolor.
#
# HA: There is a significant difference in the mean petal width for Virginica vs. Versicolor.

# %% [markdown]
# Takeaways:
#
# - Sepal length and Width are normally distributed
#
# - Petal Length and Width are bimodal with wide inner quartile range

# %% [markdown]
# - For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.

# %%
virg_petal_width = train_iris[train_iris.species == "virginica"].petal_width
vers_petal_width = train_iris[train_iris.species == "versicolor"].petal_width

# %%
virg_petal_width.head()

# %% [markdown]
# H0: There is no difference between the virginica and the versicolor petal width.
#
# HA: The virginica petal width is significantly smaller or larger than the versicolor petal width.

# %%
alpha = 0.05

# %%
stats.mannwhitneyu( virg_petal_width, vers_petal_width)
#Output: MannwhitneyuResult(statistic=2451.0, pvalue=9.698045444914185e-17)

# %% [markdown]
# The p-value is smaller than our significance level (9.698045444914185e-17 versus 0.05) so we reject the null hypothesis.

# %% [markdown]
# Takeaway: sepal length, petal length, and petal width seem to be good indications of species. Sepal width is too close to tell.

# %%
virg_petal_length = train_iris[train_iris.species == "virginica"].petal_length
vers_petal_length = train_iris[train_iris.species == "versicolor"].petal_length

# %%
virg_petal_length.head()

# %% [markdown]
# H0: There is no difference between the virginica and the versicolor petal length.
#
# HA: The virginica petal length is significantly smaller or larger than the versicolor petal length.

# %%
stats.mannwhitneyu( virg_petal_length, vers_petal_length)
#Output: MannwhitneyuResult(statistic=2451.0, pvalue=9.698045444914185e-17)

# %% [markdown]
# Reject the H0, there is a difference between the virginica and versicolor petal length.

# %% [markdown]
# ### 4. Multivariate Stats

# %% [markdown]
# - Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
sns.pairplot(data=train_iris, hue='species', vars=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

# %% [markdown]
# - Visualize two numeric variables of the species. Hint: sns.relplot with hue or col

# %%
sns.relplot(data=train_iris, x = 'petal_length', y= 'petal_width', hue='species')

# %% [markdown]
# - Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
sns.swarmplot(data=train_iris, x = 'petal_length', hue = 'species')

# %%
sns.swarmplot(data=train_iris, x = 'petal_width', hue='species')

# %%
sns.swarmplot(data=train_iris, x = 'sepal_width', hue='species')

# %%
sns.swarmplot(data=train_iris, x = 'sepal_length', hue='species')

# %% [markdown]
# - Ask a specific question of the data, such as: is the sepal area signficantly different in virginica compared to setosa? Answer the question through both a plot and using a mann-whitney or t-test. If you use a t-test, be sure assumptions are met (independence, normality, equal variance).

# %%
virg_petal_area = train_iris[train_iris.species == "virginica"].petal_width * train_iris[train_iris.species == "virginica"].petal_length
vers_petal_area = train_iris[train_iris.species == "versicolor"].petal_width * train_iris[train_iris.species == "versicolor"].petal_length
seto_petal_area = train_iris[train_iris.species == "setosa"].petal_width * train_iris[train_iris.species == "setosa"].petal_length

# %%
virg_sepal_area = train_iris[train_iris.species == "virginica"].sepal_width * train_iris[train_iris.species == "virginica"].sepal_length
vers_sepal_area = train_iris[train_iris.species == "versicolor"].sepal_width * train_iris[train_iris.species == "versicolor"].sepal_length
seto_sepal_area = train_iris[train_iris.species == "setosa"].sepal_width * train_iris[train_iris.species == "setosa"].sepal_length

# %%
train_iris['petal_area'] = train_iris.petal_width * train_iris.petal_length
train_iris['sepal_area'] = train_iris.sepal_width * train_iris.sepal_length

# %%
train_iris.info()

# %%
sns.scatterplot(data=train_iris, x='sepal_area', y='petal_area', hue='species')

# %%
#train_iris.melt(id_vars=['species'], var_name='treatment', value_name='response')

# %% [markdown]
# H0: There is no difference between the virginica and the setosa sepal area.
#
# HA: The virginica sepal area is significantly smaller or larger than the setosa sepal area.

# %%
seto_sepal_area = train_iris[train_iris['species'] == 'setosa'].sepal_area
virg_sepal_area = train_iris[train_iris['species'] == 'virginica'].sepal_area

# %%
stats.mannwhitneyu(virg_sepal_area, seto_sepal_area)

# %% [markdown]
# Takeway: The HO is low so we reject it in favor of the HA!

# %% [markdown]
# - Document takeaways and any actions.

# %% [markdown]
# It appears petal area is the best indicator of species. Plant age might affect this.
